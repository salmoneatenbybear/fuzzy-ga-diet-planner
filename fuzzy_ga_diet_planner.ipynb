# %% [markdown]
# # **Fuzzy-GA Diet Planner**

# %%
# !wget -O foundation_foods.zip "https://fdc.nal.usda.gov/fdc-datasets/FoodData_Central_foundation_food_csv_2024-10-31.zip"

# !unzip foundation_foods.zip
# Out:
# --2025-03-31 09:39:57--  https://fdc.nal.usda.gov/fdc-datasets/FoodData_Central_foundation_food_csv_2024-10-31.zip
# Resolving fdc.nal.usda.gov (fdc.nal.usda.gov)... 52.245.234.40
# Connecting to fdc.nal.usda.gov (fdc.nal.usda.gov)|52.245.234.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3258886 (3.1M) [application/zip]
# Saving to: ‘foundation_foods.zip’
#
# foundation_foods.zi 100%[===================>]   3.11M  --.-KB/s    in 0.1s
#
# 2025-03-31 09:39:57 (22.2 MB/s) - ‘foundation_foods.zip’ saved [3258886/3258886]
#
# Archive:  foundation_foods.zip
#    creating: FoodData_Central_foundation_food_csv_2024-10-31/
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/food_update_log_entry.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/agricultural_samples.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/Download API Field Descriptions.xlsx
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/input_food.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/food_attribute_type.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/lab_method_code.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/measure_unit.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/food_nutrient_conversion_factor.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/nutrient.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/sub_sample_food.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/market_acquisition.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/food_attribute.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/sample_food.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/food.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/food_protein_conversion_factor.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/lab_method.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/sub_sample_result.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/food_category.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/lab_method_nutrient.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/food_nutrient.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/acquisition_samples.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/food_calorie_conversion_factor.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/food_component.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/foundation_food.csv
#   inflating: FoodData_Central_foundation_food_csv_2024-10-31/food_portion.csv

# %%
import pandas as pd

foundation_df = pd.read_csv("FoodData_Central_foundation_food_csv_2024-10-31/foundation_food.csv")

print("Foundation Foods Sample:")
print(foundation_df.head(50))
# Out:
# Foundation Foods Sample:
#     fdc_id  NDB_number                                           footnote
# 0   321358       16158                                                NaN
# 1   321360      100147                                                NaN
# 2   321611       11056                                                NaN
# 3   323121        7022                                                NaN
# 4   323294       12563                 Other phytosterols = 34.67 mg/100g
# 5   323505       11233                                                NaN
# 6   323604        1171                                                NaN
# 7   323697        1172                                                NaN
# 8   323793        1173                                                NaN
# 9   324317       11296                                                NaN
# 10  324653       11937                                                NaN
# 11  325036        1032                                                NaN
# 12  325198        1042                                                NaN
# 13  325287        9123                                                NaN
# 14  325430        9236                                                NaN
# 15  325524       12537                                                NaN
# 16  325871       18069                                                NaN
# 17  326196       11236                                                NaN
# 18  326698        2046                                                NaN
# 19  327046        9148                                                NaN
# 20  327357        9191                                                NaN
# 21  328637        1009                                                NaN
# 22  328841        1015                                                NaN
# 23  329370        1029                                                NaN
# 24  329490        1133                                                NaN
# 25  329596        1126                                                NaN
# 26  329716        1137                                                NaN
# 27  330137        1256                                                NaN
# 28  330415        1285                                                NaN
# 29  330458        4047                                                NaN
# 30  331897        5671                                                NaN
# 31  331960        5746                                                NaN
# 32  332282        6931                                                NaN
# 33  332397        7028                                                NaN
# 34  332791        9533                                                NaN
# 35  333008      100192                                                NaN
# 36  333281      100193                                                NaN
# 37  333374       15033           May contain additives to retain moisture
# 38  333476       15066           May contain additives to retain moisture
# 39  334194       15121                                                NaN
# 40  334536       36602                                                NaN
# 41  334628       36412                                                NaN
# 42  334720       36408                                                NaN
# 43  335240       18075                                                NaN
# 44  746758       23377  Source number reflects the actual number of sa...
# 45  746759       23385  Source number reflects the actual number of sa...
# 46  746760       23362  Source number reflects the actual number of sa...
# 47  746761       23359  Source number reflects the actual number of sa...
# 48  746762       13468  Source number reflects the actual number of sa...
# 49  746763       13236  Source number reflects the actual number of sa...

# %%
foundation_nutrient_df = pd.read_csv("FoodData_Central_foundation_food_csv_2024-10-31/food_nutrient.csv")
print("Foundation Foods Nutrient Sample:")
print(foundation_nutrient_df.head(50))
# Out:
# Foundation Foods Nutrient Sample:
#          id  fdc_id  nutrient_id   amount  data_points  derivation_id  min  \
# 0   2201847  319877         1051   56.300          1.0            1.0  NaN
# 1   2201845  319877         1002    1.280          1.0            1.0  NaN
# 2   2201846  319877         1004   19.000          1.0            1.0  NaN
# 3   2201844  319877         1007    1.980          1.0            1.0  NaN
# 4   2201852  319878         1091  188.000          1.0            1.0  NaN
# 5   2201851  319878         1101    1.210          1.0            1.0  NaN
# 6   2201853  319878         1092  326.000          1.0            1.0  NaN
# 7   2201848  319878         1087   46.000          1.0            1.0  NaN
# 8   2201854  319878         1093  446.000          1.0            1.0  NaN
# 9   2201850  319878         1090   75.900          1.0            1.0  NaN
# 10  2201849  319878         1089    2.330          1.0            1.0  NaN
# 11  2201856  319878         1098    0.380          1.0            1.0  NaN
# 12  2201855  319878         1095    1.500          1.0            1.0  NaN
# 13  2201860  319882         1051   56.100          1.0            1.0  NaN
# 14  2201857  319882         1007    1.990          1.0            1.0  NaN
# 15  2201858  319882         1002    1.290          1.0            1.0  NaN
# 16  2201859  319882         1004   18.700          1.0            1.0  NaN
# 17  2201861  319883         1170    0.370          1.0            1.0  NaN
# 18  2201866  319884         1101    1.200          1.0            1.0  NaN
# 19  2201862  319884         1093  444.000          1.0            1.0  NaN
# 20  2201870  319884         1087   57.000          1.0            1.0  NaN
# 21  2201867  319884         1090   81.400          1.0            1.0  NaN
# 22  2201864  319884         1092  327.000          1.0            1.0  NaN
# 23  2201869  319884         1098    0.394          1.0            1.0  NaN
# 24  2201865  319884         1091  190.000          1.0            1.0  NaN
# 25  2201868  319884         1089    2.960          1.0            1.0  NaN
# 26  2201863  319884         1095    1.470          1.0            1.0  NaN
# 27  2201874  319892         1051   58.200          1.0            1.0  NaN
# 28  2201873  319892         1004   16.600          1.0            1.0  NaN
# 29  2201872  319892         1002    1.250          1.0            1.0  NaN
# 30  2201871  319892         1007    2.020          1.0            1.0  NaN
# 31  2201880  319893         1093  387.000          1.0            1.0  NaN
# 32  2201878  319893         1091  179.000          1.0            1.0  NaN
# 33  2201879  319893         1092  320.000          1.0            1.0  NaN
# 34  2201876  319893         1090   69.800          1.0            1.0  NaN
# 35  2201877  319893         1101    1.180          1.0            1.0  NaN
# 36  2201881  319893         1095    1.420          1.0            1.0  NaN
# 37  2201875  319893         1089    2.720          1.0            1.0  NaN
# 38  2201883  319893         1087   46.000          1.0            1.0  NaN
# 39  2201882  319893         1098    0.382          1.0            1.0  NaN
# 40  2201887  319899         1051   57.600          1.0            1.0  NaN
# 41  2201885  319899         1002    1.100          1.0            1.0  NaN
# 42  2201884  319899         1007    1.980          1.0            1.0  NaN
# 43  2201886  319899         1004   19.100          1.0            1.0  NaN
# 44  2201888  319900         1089    2.070          1.0            1.0  NaN
# 45  2201893  319900         1090   68.500          1.0            1.0  NaN
# 46  2201894  319900         1095    1.280          1.0            1.0  NaN
# 47  2201892  319900         1091  143.000          1.0            1.0  NaN
# 48  2201889  319900         1098    0.309          1.0            1.0  NaN
# 49  2201891  319900         1101    0.950          1.0            1.0  NaN
#
#     max  median footnote  min_year_acquired
# 0   NaN     NaN      NaN                NaN
# 1   NaN     NaN      NaN                NaN
# 2   NaN     NaN      NaN                NaN
# 3   NaN     NaN      NaN                NaN
# 4   NaN     NaN      NaN                NaN
# 5   NaN     NaN      NaN                NaN
# 6   NaN     NaN      NaN                NaN
# 7   NaN     NaN      NaN                NaN
# 8   NaN     NaN      NaN                NaN
# 9   NaN     NaN      NaN                NaN
# 10  NaN     NaN      NaN                NaN
# 11  NaN     NaN      NaN                NaN
# 12  NaN     NaN      NaN                NaN
# 13  NaN     NaN      NaN                NaN
# 14  NaN     NaN      NaN                NaN
# 15  NaN     NaN      NaN                NaN
# 16  NaN     NaN      NaN                NaN
# 17  NaN     NaN      NaN                NaN
# 18  NaN     NaN      NaN                NaN
# 19  NaN     NaN      NaN                NaN
# 20  NaN     NaN      NaN                NaN
# 21  NaN     NaN      NaN                NaN
# 22  NaN     NaN      NaN                NaN
# 23  NaN     NaN      NaN                NaN
# 24  NaN     NaN      NaN                NaN
# 25  NaN     NaN      NaN                NaN
# 26  NaN     NaN      NaN                NaN
# 27  NaN     NaN      NaN                NaN
# 28  NaN     NaN      NaN                NaN
# 29  NaN     NaN      NaN                NaN
# 30  NaN     NaN      NaN                NaN
# 31  NaN     NaN      NaN                NaN
# 32  NaN     NaN      NaN                NaN
# 33  NaN     NaN      NaN                NaN
# 34  NaN     NaN      NaN                NaN
# 35  NaN     NaN      NaN                NaN
# 36  NaN     NaN      NaN                NaN
# 37  NaN     NaN      NaN                NaN
# 38  NaN     NaN      NaN                NaN
# 39  NaN     NaN      NaN                NaN
# 40  NaN     NaN      NaN                NaN
# 41  NaN     NaN      NaN                NaN
# 42  NaN     NaN      NaN                NaN
# 43  NaN     NaN      NaN                NaN
# 44  NaN     NaN      NaN                NaN
# 45  NaN     NaN      NaN                NaN
# 46  NaN     NaN      NaN                NaN
# 47  NaN     NaN      NaN                NaN
# 48  NaN     NaN      NaN                NaN
# 49  NaN     NaN      NaN                NaN
# <ipython-input-4-37982be7bead>:2: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   foundation_nutrient_df = pd.read_csv("FoodData_Central_foundation_food_csv_2024-10-31/food_nutrient.csv")

# %%
foundation_nutrient_desc = pd.read_csv("FoodData_Central_foundation_food_csv_2024-10-31/nutrient.csv")
print("Nutrient Descriptions Sample:")
print(foundation_nutrient_desc.head(50))
# Out:
# Nutrient Descriptions Sample:
#       id                                  name unit_name  nutrient_nbr  \
# 0   2047      Energy (Atwater General Factors)      KCAL         957.0
# 1   2048     Energy (Atwater Specific Factors)      KCAL         958.0
# 2   1001                                Solids         G         201.0
# 3   1002                              Nitrogen         G         202.0
# 4   1003                               Protein         G         203.0
# 5   1004                     Total lipid (fat)         G         204.0
# 6   1005           Carbohydrate, by difference         G         205.0
# 7   1006  Fiber, crude (DO NOT USE - Archived)         G         206.0
# 8   1007                                   Ash         G         207.0
# 9   1008                                Energy      KCAL         208.0
# 10  1009                                Starch         G         209.0
# 11  1010                               Sucrose         G         210.0
# 12  1011                               Glucose         G         211.0
# 13  1012                              Fructose         G         212.0
# 14  1013                               Lactose         G         213.0
# 15  1014                               Maltose         G         214.0
# 16  1015                               Amylose         G         218.0
# 17  1016                           Amylopectin         G         219.0
# 18  1017                                Pectin         G         220.0
# 19  1018                        Alcohol, ethyl         G         221.0
# 20  1019                              Pentosan         G         222.0
# 21  1020                              Pentoses         G         223.0
# 22  1021                         Hemicellulose         G         224.0
# 23  1022                             Cellulose         G         225.0
# 24  1023                                    pH        PH         226.0
# 25  1024                      Specific Gravity     SP_GR         227.0
# 26  1025                         Organic acids         G         229.0
# 27  1026                           Acetic acid        MG         230.0
# 28  1027                         Aconitic acid        MG         231.0
# 29  1028                          Benzoic acid        MG         232.0
# 30  1029                       Chelidonic acid        MG         233.0
# 31  1030                      Chlorogenic acid        MG         234.0
# 32  1031                         Cinnamic acid        MG         235.0
# 33  1032                           Citric acid        MG         236.0
# 34  1033                          Fumaric acid        MG         237.0
# 35  1034                     Galacturonic acid        MG         238.0
# 36  1035                           Gallic acid        MG         239.0
# 37  1036                         Glycolic acid        MG         240.0
# 38  1037                        Isocitric acid        MG         241.0
# 39  1038                           Lactic acid        MG         242.0
# 40  1039                            Malic acid        MG         243.0
# 41  1040                      Oxaloacetic acid        MG         244.0
# 42  1041                           Oxalic acid        MG         245.0
# 43  1042                           Phytic acid        MG         246.0
# 44  1043                          Pyruvic acid        MG         247.0
# 45  1044                           Quinic acid        MG         248.0
# 46  1045                        Salicylic acid        MG         249.0
# 47  1046                         Succinic acid        MG         250.0
# 48  1047                         Tartaric acid        MG         251.0
# 49  1048                          Ursolic acid        MG         252.0
#
#         rank
# 0      280.0
# 1      290.0
# 2      200.0
# 3      500.0
# 4      600.0
# 5      800.0
# 6     1110.0
# 7   999999.0
# 8     1000.0
# 9      300.0
# 10    2200.0
# 11    1600.0
# 12    1700.0
# 13    1800.0
# 14    1900.0
# 15    2000.0
# 16  999999.0
# 17  999999.0
# 18  999999.0
# 19   18200.0
# 20  999999.0
# 21  999999.0
# 22  999999.0
# 23  999999.0
# 24  999999.0
# 25    8955.0
# 26    2850.0
# 27    2900.0
# 28    3000.0
# 29    3100.0
# 30    3200.0
# 31    3300.0
# 32    3400.0
# 33    3500.0
# 34    3600.0
# 35    3700.0
# 36    3800.0
# 37    3900.0
# 38    4000.0
# 39    4100.0
# 40    4200.0
# 41    4300.0
# 42    4400.0
# 43    4500.0
# 44    4600.0
# 45    4700.0
# 46    4800.0
# 47    4900.0
# 48    5000.0
# 49    5100.0

# %%
print("Nutrient Data Columns:")
print(foundation_nutrient_df.columns)
# Out:
# Nutrient Data Columns:
# Index(['id', 'fdc_id', 'nutrient_id', 'amount', 'data_points', 'derivation_id',
#        'min', 'max', 'median', 'footnote', 'min_year_acquired'],
#       dtype='object')

# %%
foundation_nutrient_full = pd.merge(
    foundation_nutrient_df,
    foundation_nutrient_desc,
    left_on="nutrient_id",
    right_on="id",
    how="left"
)


print("Merged Nutrient Data Sample:")
print(foundation_nutrient_full.head(10))
# Out:
# Merged Nutrient Data Sample:
#       id_x  fdc_id  nutrient_id  amount  data_points  derivation_id  min  max  \
# 0  2201847  319877         1051   56.30          1.0            1.0  NaN  NaN
# 1  2201845  319877         1002    1.28          1.0            1.0  NaN  NaN
# 2  2201846  319877         1004   19.00          1.0            1.0  NaN  NaN
# 3  2201844  319877         1007    1.98          1.0            1.0  NaN  NaN
# 4  2201852  319878         1091  188.00          1.0            1.0  NaN  NaN
# 5  2201851  319878         1101    1.21          1.0            1.0  NaN  NaN
# 6  2201853  319878         1092  326.00          1.0            1.0  NaN  NaN
# 7  2201848  319878         1087   46.00          1.0            1.0  NaN  NaN
# 8  2201854  319878         1093  446.00          1.0            1.0  NaN  NaN
# 9  2201850  319878         1090   75.90          1.0            1.0  NaN  NaN
#
#    median footnote  min_year_acquired    id_y               name unit_name  \
# 0     NaN      NaN                NaN  1051.0              Water         G
# 1     NaN      NaN                NaN  1002.0           Nitrogen         G
# 2     NaN      NaN                NaN  1004.0  Total lipid (fat)         G
# 3     NaN      NaN                NaN  1007.0                Ash         G
# 4     NaN      NaN                NaN  1091.0      Phosphorus, P        MG
# 5     NaN      NaN                NaN  1101.0      Manganese, Mn        MG
# 6     NaN      NaN                NaN  1092.0       Potassium, K        MG
# 7     NaN      NaN                NaN  1087.0        Calcium, Ca        MG
# 8     NaN      NaN                NaN  1093.0         Sodium, Na        MG
# 9     NaN      NaN                NaN  1090.0      Magnesium, Mg        MG
#
#    nutrient_nbr    rank
# 0         255.0   100.0
# 1         202.0   500.0
# 2         204.0   800.0
# 3         207.0  1000.0
# 4         305.0  5600.0
# 5         315.0  6100.0
# 6         306.0  5700.0
# 7         301.0  5300.0
# 8         307.0  5800.0
# 9         304.0  5500.0

# %%
print("Nutrient Desc Columns:")
print(foundation_nutrient_desc.columns)
# Out:
# Nutrient Desc Columns:
# Index(['id', 'name', 'unit_name', 'nutrient_nbr', 'rank'], dtype='object')

# %%
for column in foundation_nutrient_desc.columns:
    unique_values = foundation_nutrient_desc[column].unique()
    print(f"Unique values in '{column}':")
    print(unique_values)
    print("-" * 50)
# Out:
# Unique values in 'id':
# [2047 2048 1001 1002 1003 1004 1005 1006 1007 1008 1009 1010 1011 1012
#  1013 1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026
#  1027 1028 1029 1030 1031 1032 1033 1034 1035 1036 1037 1038 1039 1040
#  1041 1042 1043 1044 1045 1046 1047 1048 1049 1050 1051 1052 1053 1054
#  1055 1056 1057 1058 1059 1060 1061 1062 1063 1064 1065 1066 1067 1068
#  1069 1070 1071 1072 1073 1074 1075 1076 1077 1078 1079 1080 1081 1082
#  1083 1084 1085 1086 1087 1088 1089 1090 1091 1092 1093 1094 1095 1096
#  1097 1098 1099 1100 1101 1102 1103 1104 1105 1106 1107 1108 1109 1110
#  1111 1112 1113 1114 1115 1116 1117 1118 1119 1120 1121 1122 1123 1124
#  1125 1126 1127 1128 1129 1130 1131 1132 1133 1134 1135 1136 1137 1138
#  1139 1140 1141 1142 1143 1144 1145 1146 1147 1148 1149 1150 1151 1152
#  1153 1154 1155 1156 1157 1158 1159 1160 1161 1162 1163 1164 1165 1166
#  1167 1168 1169 1170 1171 1172 1173 1174 1175 1176 1177 1178 1179 1180
#  1181 1182 1183 1184 1185 1186 1187 1188 1189 1190 1191 1192 1193 1194
#  1195 1196 1197 1198 1199 1200 1201 1202 1203 1204 1205 1206 1207 1208
#  1209 1210 1211 1212 1213 1214 1215 1216 1217 1218 1219 1220 1221 1222
#  1223 1224 1225 1226 1227 1228 1229 1230 1231 1232 1233 1234 1235 1236
#  1237 1238 1239 1240 1241 1242 1243 1244 1245 1246 1247 1248 1249 1250
#  1251 1252 1253 1254 1255 1256 1257 1258 1259 1260 1261 1262 1263 1264
#  1265 1266 1267 1268 1269 1270 1271 1272 1273 1274 1275 1276 1277 1278
#  1279 1280 1281 1283 1284 1285 1286 1287 1288 1289 1290 1291 1292 1293
#  1294 1295 1296 1297 1298 1299 1300 1301 1302 1303 1304 1305 1306 1307
#  1308 1309 1310 1311 1312 1313 1314 1315 1316 1317 1318 1319 1320 1321
#  1322 1323 1324 1325 1326 1327 1328 1329 1330 1331 1332 1333 1334 1335
#  1336 1337 1338 1339 1340 1341 1342 1343 1344 1345 1346 1347 1348 1349
#  1350 1351 1352 1353 1354 1355 1356 1357 1358 1359 1360 1361 1362 1363
#  1364 1365 1366 1367 1368 1369 1370 1371 1372 1373 1374 1375 1376 1377
#  1378 1379 1380 1381 1382 1383 1384 1385 1386 1387 1388 1389 1390 1391
#  1392 1393 1394 1395 1396 1397 1398 1399 1400 1401 1402 1403 1404 1405
#  1406 1407 1408 1409 1410 1411 1412 1413 1414 2000 2003 2004 2005 2006
#  2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020
#  2021 2022 2023 2024 2025 2026 2027 2028 2029 2032 2033 2034 2035 2036
#  2037 2038 2039 2040 2041 2042 2043 2044 2045 2046 2055 2054 2053 2052
#  2049 2050 2051 2057 2058 2059 2060 2061 2062 2063 2064 2065 2068 2067
#  2069]
# --------------------------------------------------
# Unique values in 'name':
# ['Energy (Atwater General Factors)' 'Energy (Atwater Specific Factors)'
#  'Solids' 'Nitrogen' 'Protein' 'Total lipid (fat)'
#  'Carbohydrate, by difference' 'Fiber, crude (DO NOT USE - Archived)'
#  'Ash' 'Energy' 'Starch' 'Sucrose' 'Glucose' 'Fructose' 'Lactose'
#  'Maltose' 'Amylose' 'Amylopectin' 'Pectin' 'Alcohol, ethyl' 'Pentosan'
#  'Pentoses' 'Hemicellulose' 'Cellulose' 'pH' 'Specific Gravity'
#  'Organic acids' 'Acetic acid' 'Aconitic acid' 'Benzoic acid'
#  'Chelidonic acid' 'Chlorogenic acid' 'Cinnamic acid' 'Citric acid'
#  'Fumaric acid' 'Galacturonic acid' 'Gallic acid' 'Glycolic acid'
#  'Isocitric acid' 'Lactic acid' 'Malic acid' 'Oxaloacetic acid'
#  'Oxalic acid' 'Phytic acid' 'Pyruvic acid' 'Quinic acid' 'Salicylic acid'
#  'Succinic acid' 'Tartaric acid' 'Ursolic acid' 'Solids, non-fat'
#  'Carbohydrate, by summation' 'Water' 'Adjusted Nitrogen'
#  'Adjusted Protein' 'Piperine' 'Mannitol' 'Sorbitol' 'Caffeine'
#  'Theobromine' 'Nitrates' 'Nitrites' 'Nitrosamine,total' 'Sugars, Total'
#  'Solids, soluble' 'Glycogen'
#  'Fiber, neutral detergent (DO NOT USE - Archived)' 'Reducing sugars'
#  'Beta-glucans' 'Oligosaccharides' 'Nonstarch polysaccharides'
#  'Resistant starch' 'Carbohydrate, other' 'Arabinose' 'Xylose' 'Galactose'
#  'Raffinose' 'Stachyose' 'Xylitol' 'Fiber, total dietary' 'Lignin'
#  'Ribose' 'Fiber, soluble' 'Theophylline' 'Fiber, insoluble'
#  'Total fat (NLEA)' 'Total sugar alcohols' 'Calcium, Ca' 'Chlorine, Cl'
#  'Iron, Fe' 'Magnesium, Mg' 'Phosphorus, P' 'Potassium, K' 'Sodium, Na'
#  'Sulfur, S' 'Zinc, Zn' 'Chromium, Cr' 'Cobalt, Co' 'Copper, Cu'
#  'Fluoride, F' 'Iodine, I' 'Manganese, Mn' 'Molybdenum, Mo' 'Selenium, Se'
#  'Vitamin A, IU' 'Retinol' 'Vitamin A, RAE' 'Carotene, beta'
#  'Carotene, alpha' 'Vitamin E (alpha-tocopherol)'
#  'Vitamin D (D2 + D3), International Units' 'Vitamin D2 (ergocalciferol)'
#  'Vitamin D3 (cholecalciferol)' '25-hydroxycholecalciferol'
#  'Vitamin D (D2 + D3)' '25-hydroxyergocalciferol' 'Phytoene' 'Phytofluene'
#  'Carotene, gamma' 'Zeaxanthin' 'Cryptoxanthin, beta' 'Lutein' 'Lycopene'
#  'Lutein + zeaxanthin' 'Vitamin E (label entry primarily)'
#  'Tocopherol, beta' 'Tocopherol, gamma' 'Tocopherol, delta'
#  'Tocotrienol, alpha' 'Tocotrienol, beta' 'Tocotrienol, gamma'
#  'Tocotrienol, delta' 'Aluminum, Al' 'Antimony, Sb' 'Arsenic, As'
#  'Barium, Ba' 'Beryllium, Be' 'Boron, B' 'Bromine, Br' 'Cadmium, Cd'
#  'Gold, Au' 'Iron, heme' 'Iron, non-heme' 'Lead, Pb' 'Lithium, Li'
#  'Mercury, Hg' 'Nickel, Ni' 'Rubidium, Rb'
#  'Fluoride - DO NOT USE; use 313' 'Salt, NaCl' 'Silicon, Si' 'Silver, Ag'
#  'Strontium, Sr' 'Tin, Sn' 'Titanium, Ti' 'Vanadium, V' 'Vitamin A, RE'
#  'Carotene' 'Vitamin E' 'cis-beta-Carotene' 'cis-Lycopene'
#  'cis-Lutein/Zeaxanthin' 'Vitamin C, total ascorbic acid'
#  'Vitamin C, reduced ascorbic acid' 'Vitamin C, dehydro ascorbic acid'
#  'Thiamin' 'Riboflavin' 'Niacin' 'Niacin from tryptophan, determined'
#  'Niacin equivalent N406 +N407' 'Pantothenic acid'
#  'Vitamin B-6, pyridoxine, alcohol form'
#  'Vitamin B-6, pyridoxal, aldehyde form'
#  'Vitamin B-6, pyridoxamine, amine form' 'Vitamin B-6, N411 + N412 +N413'
#  'Vitamin B-6' 'Biotin' 'Folate, total' 'Vitamin B-12' 'Folate, free'
#  'Choline, total' 'Inositol' 'Inositol phosphate'
#  'Vitamin K (Menaquinone-4)' 'Vitamin K (Dihydrophylloquinone)'
#  'Vitamin K (phylloquinone)' 'Folic acid' 'Folate, food'
#  '5-methyl tetrahydrofolate (5-MTHF)' 'Folate, not 5-MTHF' 'Folate, DFE'
#  '10-Formyl folic acid (10HCOFA)' '5-Formyltetrahydrofolic acid (5-HCOH4'
#  'Tetrahydrofolic acid (THF)' 'Choline, free'
#  'Choline, from phosphocholine' 'Choline, from phosphotidyl choline'
#  'Choline, from glycerophosphocholine' 'Betaine'
#  'Choline, from sphingomyelin' 'p-Hydroxy benzoic acid' 'Caffeic acid'
#  'p-Coumaric acid' 'Ellagic acid' 'Ferrulic acid' 'Gentisic acid'
#  'Tyrosol' 'Vanillic acid' 'Phenolic acids, total' 'Polyphenols, total'
#  'Tryptophan' 'Threonine' 'Isoleucine' 'Leucine' 'Lysine' 'Methionine'
#  'Cystine' 'Phenylalanine' 'Tyrosine' 'Valine' 'Arginine' 'Histidine'
#  'Alanine' 'Aspartic acid' 'Glutamic acid' 'Glycine' 'Proline' 'Serine'
#  'Hydroxyproline' 'Cysteine and methionine(sulfer containig AA)'
#  'Phenylalanine and tyrosine (aromatic  AA)' 'Asparagine' 'Cysteine'
#  'Glutamine' 'Taurine' 'Sugars, added' 'Sugars, intrinsic'
#  'Calcium, added' 'Iron, added' 'Calcium, intrinsic' 'Iron, intrinsic'
#  'Vitamin C, added' 'Vitamin E, added' 'Thiamin, added'
#  'Riboflavin, added' 'Niacin, added' 'Vitamin B-12, added'
#  'Vitamin C, intrinsic' 'Vitamin E, intrinsic' 'Thiamin, intrinsic'
#  'Riboflavin, intrinsic' 'Niacin, intrinsic' 'Vitamin B-12, intrinsic'
#  'Cholesterol' 'Glycerides' 'Phospholipids' 'Glycolipids'
#  'Fatty acids, total trans' 'Fatty acids, total saturated' 'SFA 4:0'
#  'SFA 6:0' 'SFA 8:0' 'SFA 10:0' 'SFA 12:0' 'SFA 14:0' 'SFA 16:0'
#  'SFA 18:0' 'SFA 20:0' 'MUFA 18:1' 'PUFA 18:2' 'PUFA 18:3' 'PUFA 20:4'
#  'PUFA 22:6 n-3 (DHA)' 'SFA 22:0' 'MUFA 14:1' 'MUFA 16:1' 'PUFA 18:4'
#  'MUFA 20:1' 'PUFA 20:5 n-3 (EPA)' 'MUFA 22:1' 'PUFA 22:5 n-3 (DPA)'
#  'TFA 14:1 t' 'Phytosterols' 'Ergosterol' 'Stigmasterol' 'Campesterol'
#  'Brassicasterol' 'Beta-sitosterol' 'Campestanol'
#  'Unsaponifiable matter (lipids)'
#  'Fatty acids, other than 607-615, 617-621, 624-632, 652-654, 686-689)'
#  'Fatty acids, total monounsaturated' 'Fatty acids, total polyunsaturated'
#  'Beta-sitostanol' 'Delta-7-avenasterol' 'Delta-5-avenasterol'
#  'Alpha-spinasterol' 'Phytosterols, other' 'SFA 15:0' 'SFA 17:0'
#  'SFA 24:0' 'Wax Esters(Total Wax)' 'TFA 16:1 t' 'TFA 18:1 t' 'TFA 22:1 t'
#  'TFA 18:2 t not further defined' 'PUFA 18:2 i' 'PUFA 18:2 t,c'
#  'PUFA 18:2 c,t' 'TFA 18:2 t,t' 'PUFA 18:2 CLAs' 'MUFA 24:1 c'
#  'PUFA 20:2 n-6 c,c' 'MUFA 16:1 c' 'MUFA 18:1 c' 'PUFA 18:2 n-6 c,c'
#  'MUFA 22:1 c' 'Fatty acids, saturated, other'
#  'Fatty acids, monounsat., other' 'Fatty acids, polyunsat., other'
#  'PUFA 18:3 n-6 c,c,c' 'SFA 19:0' 'MUFA 17:1' 'PUFA 16:2' 'PUFA 20:3'
#  'Fatty acids, total sat., NLEA' 'Fatty acids, total monounsat., NLEA'
#  'Fatty acids, total polyunsat., NLEA'
#  'Fatty acids, total trans-monoenoic' 'Fatty acids, total trans-dienoic'
#  'Fatty acids, total trans-polyenoic' 'SFA 13:0' 'MUFA 15:1' 'PUFA 22:2'
#  'SFA 11:0' 'ORAC, Hydrophyllic' 'ORAC, Lipophillic' 'ORAC, Total'
#  'Total Phenolics' 'Daidzein' 'Genistein' 'Glycitein' 'Isoflavones'
#  'Biochanin A' 'Formononetin' 'Coumestrol' 'Flavonoids, total'
#  'Anthocyanidins' 'Cyanidin' 'Proanthocyanidin (dimer-A linkage)'
#  'Proanthocyanidin monomers' 'Proanthocyanidin dimers'
#  'Proanthocyanidin trimers' 'Proanthocyanidin 4-6mers'
#  'Proanthocyanidin 7-10mers' 'Proanthocyanidin polymers (>10mers)'
#  'Delphinidin' 'Malvidin' 'Pelargonidin' 'Peonidin' 'Petunidin'
#  'Flavans, total' 'Catechins, total' 'Catechin' 'Epigallocatechin'
#  'Epicatechin' 'Epicatechin-3-gallate' 'Epigallocatechin-3-gallate'
#  'Procyanidins, total' 'Theaflavins' 'Thearubigins' 'Flavanones, total'
#  'Eriodictyol' 'Hesperetin' 'Isosakuranetin' 'Liquiritigenin' 'Naringenin'
#  'Flavones, total' 'Apigenin' 'Chrysoeriol' 'Diosmetin' 'Luteolin'
#  'Nobiletin' 'Sinensetin' 'Tangeretin' 'Flavonols, total' 'Isorhamnetin'
#  'Kaempferol' 'Limocitrin' 'Myricetin' 'Quercetin' 'Theogallin'
#  "Theaflavin -3,3' -digallate" "Theaflavin -3' -gallate"
#  'Theaflavin -3 -gallate' '(+) -Gallo catechin' '(+)-Catechin 3-gallate'
#  '(+)-Gallocatechin 3-gallate' 'Mannose' 'Triose' 'Tetrose'
#  'Other Saccharides' 'Inulin' 'PUFA 18:3 n-3 c,c,c (ALA)' 'PUFA 20:3 n-3'
#  'PUFA 20:3 n-6' 'PUFA 20:4 n-3' 'PUFA 20:4 n-6' 'PUFA 18:3i' 'PUFA 21:5'
#  'PUFA 22:4' 'MUFA 18:1-11 t (18:1t n-7)' 'MUFA 18:1-11 c (18:1c n-7)'
#  'PUFA 20:3 n-9' 'Total Sugars' 'SFA 5:0' 'SFA 7:0' 'SFA 9:0' 'SFA 21:0'
#  'SFA 23:0' 'MUFA 12:1' 'MUFA 14:1 c' 'MUFA 17:1 c' 'TFA 17:1 t'
#  'MUFA 20:1 c' 'TFA 20:1 t' 'MUFA 22:1 n-9' 'MUFA 22:1 n-11' 'PUFA 18:2 c'
#  'TFA 18:2 t' 'PUFA 18:3 c' 'TFA 18:3 t' 'PUFA 20:3 c' 'PUFA 22:3'
#  'PUFA 20:4c' 'PUFA 20:5c' 'PUFA 22:5 c' 'PUFA 22:6 c' 'PUFA 20:2 c'
#  'Proximate' 'trans-beta-Carotene' 'trans-Lycopene' 'Cryptoxanthin, alpha'
#  'Total dietary fiber (AOAC 2011.25)' 'Insoluble dietary fiber (IDF)'
#  'Soluble dietary fiber (SDFP+SDFS)' 'Soluble dietary fiber (SDFP)'
#  'Soluble dietary fiber (SDFS)'
#  'High Molecular Weight Dietary Fiber (HMWDF)' 'Carbohydrates'
#  'Other carotenoids' 'Tocopherols and tocotrienols' 'Amino acids'
#  'Minerals' 'Lipids' 'Proximates' 'Vitamins and Other Components'
#  'Total Tocopherols' 'Total Tocotrienols' 'Stigmastadiene'
#  'Delta-7-Stigmastenol' 'Daidzin' 'Genistin' 'Glycitin' 'Ergothioneine'
#  'Beta-glucan' 'Vitamin D4' 'Ergosta-7-enol' 'Ergosta-7,22-dienol'
#  'Ergosta-5,7-dienol' 'Verbascose'
#  'Low Molecular Weight Dietary Fiber (LMWDF)' 'Vitamin A' 'Glutathione']
# --------------------------------------------------
# Unique values in 'unit_name':
# ['KCAL' 'G' 'PH' 'SP_GR' 'MG' 'kJ' 'UG' 'IU' 'MCG_RE' 'MG_ATE' 'UMOL_TE'
#  'MG_GAE']
# --------------------------------------------------
# Unique values in 'nutrient_nbr':
# [957.   958.   201.   202.   203.   204.   205.   206.   207.   208.
#  209.   210.   211.   212.   213.   214.   218.   219.   220.   221.
#  222.   223.   224.   225.   226.   227.   229.   230.   231.   232.
#  233.   234.   235.   236.   237.   238.   239.   240.   241.   242.
#  243.   244.   245.   246.   247.   248.   249.   250.   251.   252.
#  253.   205.2  255.   256.   257.   259.   260.   261.   262.   263.
#  264.   265.   266.   268.   269.3  271.   272.   273.   274.   276.
#  281.   282.   283.   284.   285.   286.   287.   288.   289.   290.
#  291.   292.   294.   295.   296.   297.   298.   299.   301.   302.
#  303.   304.   305.   306.   307.   308.   309.   310.   311.   312.
#  313.   314.   315.   316.   317.   318.   319.   320.   321.   322.
#  323.   324.   325.   326.   327.   328.   329.   330.   331.   332.
#  338.2  334.   338.1  337.   338.   340.   341.   342.   343.   344.
#  345.   346.   347.   348.   349.   350.   351.   352.   354.   355.
#  356.   363.   364.   365.   367.   368.   370.   371.   373.   374.
#  375.   378.   379.   380.   385.   386.   389.   392.   393.   394.
#  321.1  337.1  338.3  401.   402.   403.   404.   405.   406.   407.
#  409.   410.   411.   412.   413.   414.   415.   416.   417.   418.
#  419.   421.   422.   423.   428.   429.   430.   431.   432.   433.
#  434.   435.   436.   437.   438.   450.   451.   452.   453.   454.
#  455.   460.   461.   462.   463.   464.   465.   466.   467.   469.
#  470.   501.   502.   503.   504.   505.   506.   507.   508.   509.
#  510.   511.   512.   513.   514.   515.   516.   517.   518.   521.
#  522.   523.   525.   526.   528.   529.   539.   549.   551.   553.
#  561.   563.   571.   573.   574.   575.   576.   578.   581.   583.
#  584.   585.   586.   588.   601.   602.   603.   604.   605.   606.
#  607.   608.   609.   610.   611.   612.   613.   614.   615.   617.
#  618.   619.   620.   621.   624.   625.   626.   627.   628.   629.
#  630.   631.   821.   636.   637.   638.   639.   640.   641.   642.
#  643.   644.   645.   646.   647.   648.   649.   650.   651.   652.
#  653.   654.   661.   662.   663.   664.   665.   666.   667.   668.
#  669.   670.   671.   672.   673.   674.   675.   676.   677.   678.
#  679.   685.   686.   687.   688.   689.   690.   691.   692.   693.
#  694.   695.   696.   697.   698.   699.   706.   707.   708.   709.
#  710.   711.   712.   713.   714.   715.   716.   729.   730.   731.
#  732.   733.   734.   735.   736.   737.   738.   741.   742.   743.
#  745.   746.   747.   748.   749.   750.   751.   752.   753.   754.
#  755.   756.   757.   758.   759.   760.   761.   762.   768.   770.
#  771.   772.   773.   781.   782.   783.   784.   785.   786.   787.
#  788.   789.   790.   791.   792.   793.   794.   795.   796.   801.
#  803.   804.   805.   806.   851.   852.   853.   854.   855.   856.
#  857.   858.   859.   860.   861.   269.   632.   633.   634.   681.
#  682.   635.   822.   825.   826.   829.   830.   676.1  676.2  831.
#  832.   833.   834.   835.   683.   836.   837.   838.   839.   840.
#  200.   321.2  337.2  335.   293.   293.1  293.2  954.   953.   293.3
#  956.   955.   323.99 500.   300.   950.   951.   952.      nan 717.
#  718.   719.   293.4  959.   960.   961.  ]
# --------------------------------------------------
# Unique values in 'rank':
# [2.80000e+02 2.90000e+02 2.00000e+02 5.00000e+02 6.00000e+02 8.00000e+02
#  1.11000e+03 9.99999e+05 1.00000e+03 3.00000e+02 2.20000e+03 1.60000e+03
#  1.70000e+03 1.80000e+03 1.90000e+03 2.00000e+03 1.82000e+04 8.95500e+03
#  2.85000e+03 2.90000e+03 3.00000e+03 3.10000e+03 3.20000e+03 3.30000e+03
#  3.40000e+03 3.50000e+03 3.60000e+03 3.70000e+03 3.80000e+03 3.90000e+03
#  4.00000e+03 4.10000e+03 4.20000e+03 4.30000e+03 4.40000e+03 4.50000e+03
#  4.60000e+03 4.70000e+03 4.80000e+03 4.90000e+03 5.00000e+03 5.10000e+03
#  1.12000e+03 1.00000e+02 7.00000e+02 2.50000e+03 2.60000e+03 1.83000e+04
#  1.84000e+04 4.00000e+02 1.50000e+03         nan 2.10000e+03 2.30000e+03
#  2.40000e+03 2.70000e+03 1.20000e+03 1.24000e+03 1.26000e+03 9.00000e+02
#  5.30000e+03 5.40000e+03 5.50000e+03 5.60000e+03 5.70000e+03 5.80000e+03
#  6.24100e+03 5.90000e+03 6.24400e+03 6.00000e+03 6.24000e+03 6.15000e+03
#  6.10000e+03 6.24300e+03 6.20000e+03 7.50000e+03 7.43000e+03 7.42000e+03
#  7.44000e+03 7.45000e+03 7.90500e+03 8.65000e+03 8.71000e+03 8.72000e+03
#  8.73000e+03 8.70000e+03 8.74000e+03 7.57000e+03 7.58000e+03 7.45500e+03
#  7.56400e+03 7.46000e+03 7.56200e+03 7.53000e+03 7.56000e+03 8.00000e+03
#  8.10000e+03 8.20000e+03 8.30000e+03 8.40000e+03 8.50000e+03 8.60000e+03
#  6.24500e+03 6.24200e+03 6.25000e+03 7.60000e+03 7.80000e+03 7.44200e+03
#  7.53200e+03 7.56100e+03 6.30000e+03 6.40000e+03 6.50000e+03 6.60000e+03
#  6.70000e+03 6.80000e+03 6.85000e+03 6.90000e+03 7.30000e+03 7.22000e+03
#  2.80000e+03 8.95000e+03 8.90000e+03 8.80000e+03 7.00000e+03 7.10000e+03
#  7.20000e+03 7.23000e+03 7.24000e+03 7.25000e+03 7.26000e+03 7.29000e+03
#  7.27000e+03 1.63000e+04 1.64000e+04 1.65000e+04 1.66000e+04 1.67000e+04
#  1.68000e+04 1.69000e+04 1.70000e+04 1.71000e+04 1.72000e+04 1.73000e+04
#  1.74000e+04 1.75000e+04 1.76000e+04 1.77000e+04 1.78000e+04 1.79000e+04
#  1.80000e+04 1.81000e+04 1.69500e+04 1.81500e+04 1.54000e+03 1.52000e+03
#  5.34000e+03 5.44000e+03 5.32000e+03 5.42000e+03 6.34000e+03 7.92000e+03
#  6.44000e+03 6.54000e+03 6.64000e+03 7.34000e+03 6.32000e+03 7.93000e+03
#  6.42000e+03 6.52000e+03 6.62000e+03 7.32000e+03 1.57000e+04 1.54000e+04
#  9.70000e+03 9.80000e+03 9.90000e+03 1.00000e+04 1.01000e+04 1.03000e+04
#  1.05000e+04 1.07000e+04 1.09000e+04 1.11000e+04 1.21000e+04 1.31000e+04
#  1.39000e+04 1.47000e+04 1.53000e+04 1.12000e+04 1.15000e+04 1.17000e+04
#  1.42500e+04 1.24000e+04 1.50000e+04 1.25000e+04 1.52000e+04 1.55100e+04
#  1.58000e+04 1.62200e+04 1.59000e+04 1.60000e+04 1.61000e+04 1.62000e+04
#  1.62210e+04 1.14000e+04 1.29000e+04 1.62220e+04 1.62230e+04 1.62240e+04
#  1.62250e+04 1.62270e+04 1.06000e+04 1.08000e+04 1.13000e+04 1.55200e+04
#  1.55210e+04 1.55500e+04 1.56100e+04 1.33500e+04 1.35000e+04 1.34000e+04
#  1.56150e+04 1.33000e+04 1.28000e+04 1.43000e+04 1.18000e+04 1.22000e+04
#  1.32000e+04 1.26000e+04 1.41000e+04 1.10000e+04 1.20000e+04 1.30000e+04
#  1.44000e+04 1.55000e+04 1.56010e+04 1.56190e+04 1.04000e+04 1.16000e+04
#  1.51000e+04 1.02000e+04 1.91000e+04 1.92000e+04 1.93000e+04 1.90000e+04
#  1.94000e+04 1.95000e+04 1.95100e+04 1.95200e+04 1.95300e+04 1.95400e+04
#  1.95500e+04 1.95600e+04 1.95700e+04 1.96000e+04 1.97000e+04 1.98000e+04
#  1.99000e+04 2.00000e+04 2.01000e+04 2.02000e+04 2.03000e+04 2.04000e+04
#  2.05000e+04 2.06000e+04 2.07000e+04 2.08000e+04 2.09000e+04 2.10000e+04
#  2.12000e+04 2.13000e+04 2.14000e+04 2.15000e+04 2.16000e+04 2.17000e+04
#  2.18000e+04 2.19000e+04 2.20000e+04 2.21000e+04 2.22000e+04 2.23000e+04
#  2.24000e+04 2.25000e+04 2.26000e+04 2.27000e+04 2.28000e+04 2.29000e+04
#  2.30000e+04 2.31000e+04 2.11000e+04 1.40000e+04 1.45000e+04 1.46000e+04
#  1.48000e+04 1.49000e+04 1.42000e+04 1.51600e+04 1.23100e+04 1.22100e+04
#  1.46500e+04 1.51000e+03 9.85000e+03 9.95000e+03 1.00500e+04 1.11500e+04
#  1.12500e+04 1.14500e+04 1.15010e+04 1.20010e+04 1.55250e+04 1.24010e+04
#  1.55400e+04 1.26010e+04 1.26020e+04 1.31500e+04 1.56110e+04 1.39100e+04
#  1.56600e+04 1.44500e+04 1.46750e+04 1.47500e+04 1.49500e+04 1.51500e+04
#  1.52500e+04 7.44400e+03 7.53400e+03 7.46100e+03 1.30000e+03 1.31000e+03
#  1.32000e+03 1.32400e+03 1.32600e+03 1.30500e+03 1.10000e+03 7.51000e+03
#  7.90000e+03 1.62500e+04 5.20000e+03 9.60000e+03 5.00000e+01 7.90100e+03
#  7.90200e+03 1.58010e+04 1.62260e+04 1.93100e+04 1.93200e+04 1.93300e+04
#  1.62550e+04 1.32700e+03 1.62100e+04 1.62110e+04 2.45000e+03 2.25000e+03
#  1.30600e+03 7.81000e+03 9.00000e+03]
# --------------------------------------------------

# %%
nutrient_mapping = {
    "Energy (Atwater General Factors)": "Calories",
    "Protein": "Protein_g",
    "Total lipid (fat)": "Fat_g",
    "Carbohydrate, by difference": "Carbohydrate_g",
    "Fiber, total dietary": "Fiber_g",
    "Calcium, Ca": "Calcium_mg",
    "Iron, Fe": "Iron_mg",
    "Potassium, K": "Potassium_mg",
    "Sodium, Na": "Sodium_mg",
    "Vitamin C, total ascorbic acid": "VitC_mg",
    "Vitamin A, IU": "VitA_ug",
    "Vitamin B-12": "VitB12_ug",
    "Magnesium, Mg": "Magnesium_mg"
}

print("Nutrient Mapping Dictionary:")
print(nutrient_mapping)
# Out:
# Nutrient Mapping Dictionary:
# {'Energy (Atwater General Factors)': 'Calories', 'Protein': 'Protein_g', 'Total lipid (fat)': 'Fat_g', 'Carbohydrate, by difference': 'Carbohydrate_g', 'Fiber, total dietary': 'Fiber_g', 'Calcium, Ca': 'Calcium_mg', 'Iron, Fe': 'Iron_mg', 'Potassium, K': 'Potassium_mg', 'Sodium, Na': 'Sodium_mg', 'Vitamin C, total ascorbic acid': 'VitC_mg', 'Vitamin A, IU': 'VitA_ug', 'Vitamin B-12': 'VitB12_ug', 'Magnesium, Mg': 'Magnesium_mg'}

# %%
filtered_nutrient = foundation_nutrient_full[
    foundation_nutrient_full["name"].isin(nutrient_mapping.keys())
]


nutrient_pivot = filtered_nutrient.pivot_table(
    index="fdc_id",
    columns="name",
    values="amount",
    aggfunc="first"
).reset_index()


nutrient_pivot.rename(columns=nutrient_mapping, inplace=True)

print("Pivoted Nutrient Data Sample:")
print(nutrient_pivot.head(10))
# Out:
# Pivoted Nutrient Data Sample:
# name  fdc_id  Calcium_mg  Carbohydrate_g  Calories  Fiber_g  Iron_mg  \
# 0     319877         NaN             NaN       NaN      NaN      NaN
# 1     319878        46.0             NaN       NaN      NaN     2.33
# 2     319882         NaN             NaN       NaN      NaN      NaN
# 3     319884        57.0             NaN       NaN      NaN     2.96
# 4     319892         NaN             NaN       NaN      NaN      NaN
# 5     319893        46.0             NaN       NaN      NaN     2.72
# 6     319899         NaN             NaN       NaN      NaN      NaN
# 7     319900        38.0             NaN       NaN      NaN     2.07
# 8     319908         NaN             NaN       NaN      NaN      NaN
# 9     319912        51.0             NaN       NaN      NaN     2.70
#
# name  Magnesium_mg  Potassium_mg  Protein_g  Sodium_mg  Fat_g  VitB12_ug  \
# 0              NaN           NaN        NaN        NaN   19.0        NaN
# 1             75.9         326.0        NaN      446.0    NaN        NaN
# 2              NaN           NaN        NaN        NaN   18.7        NaN
# 3             81.4         327.0        NaN      444.0    NaN        NaN
# 4              NaN           NaN        NaN        NaN   16.6        NaN
# 5             69.8         320.0        NaN      387.0    NaN        NaN
# 6              NaN           NaN        NaN        NaN   19.1        NaN
# 7             68.5         252.0        NaN      489.0    NaN        NaN
# 8              NaN           NaN        NaN        NaN   18.2        NaN
# 9             73.1         317.0        NaN      428.0    NaN        NaN
#
# name  VitC_mg
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN

# %%
foundation_combined = pd.merge(
    foundation_df,
    nutrient_pivot,
    on="fdc_id",
    how="left"
)

print("Combined Foundation Foods Data Sample:")
print(foundation_combined.head(10))
# Out:
# Combined Foundation Foods Data Sample:
#    fdc_id  NDB_number                             footnote  Calcium_mg  \
# 0  321358       16158                                  NaN        41.0
# 1  321360      100147                                  NaN        11.0
# 2  321611       11056                                  NaN        36.0
# 3  323121        7022                                  NaN        15.0
# 4  323294       12563   Other phytosterols = 34.67 mg/100g       273.0
# 5  323505       11233                                  NaN       254.0
# 6  323604        1171                                  NaN        55.0
# 7  323697        1172                                  NaN         9.0
# 8  323793        1173                                  NaN       104.0
# 9  324317       11296                                  NaN        28.0
#
#    Carbohydrate_g  Calories  Fiber_g  Iron_mg  Magnesium_mg  Potassium_mg  \
# 0           14.90     243.0      5.4     2.41          71.1         289.0
# 1            5.51      31.0      2.1     0.33          11.9         260.0
# 2            4.11      24.0      NaN     0.78          12.7          97.0
# 3            2.89     310.0      NaN     1.14          11.5         343.0
# 4           16.20     667.0     11.0     3.17         258.0         684.0
# 5            4.42      43.0      4.1     1.60          32.7         348.0
# 6            0.91     146.0      NaN     1.77          11.2         117.0
# 7            0.74      45.0      NaN     0.18          10.6         130.0
# 8            6.02     350.0      NaN     0.00          87.6         959.0
# 9           36.30     293.0      2.4     1.14          20.4         135.0
#
#    Protein_g  Sodium_mg  Fat_g  VitB12_ug  VitC_mg
# 0       7.35      438.0  17.10        NaN      0.0
# 1       0.83        6.0   0.63        NaN     27.2
# 2       1.04      282.0   0.39        NaN      NaN
# 3      11.70      872.0  28.00       0.97      NaN
# 4      20.40      256.0  57.80        NaN      0.0
# 5       2.92       53.0   1.49        NaN     93.4
# 6      12.30      121.0  10.30        NaN      NaN
# 7      10.10      144.0   0.16        NaN      NaN
# 8      79.90     1250.0   0.65        NaN      NaN
# 9       4.52      374.0  14.40        NaN      1.6

# %%
import pandas as pd

nutrients = [
    "Calories", "Protein_g", "Fat_g", "Carbohydrate_g", "Fiber_g",
    "Calcium_mg", "Iron_mg", "Potassium_mg", "Sodium_mg",
    "VitC_mg", "VitB12_ug", "Magnesium_mg"
]

print("Summary statistics for nutrient columns:")
print(foundation_combined[nutrients].describe())
# Out:
# Summary statistics for nutrient columns:
#          Calories   Protein_g       Fat_g  Carbohydrate_g     Fiber_g  \
# count  286.000000  305.000000  307.000000      286.000000  166.000000
# mean   204.052186   10.514213    9.097894       21.059480    4.314305
# std    188.126262   10.549917   16.720474       26.173665    4.667475
# min      0.000000    0.000000    0.000000        0.000000    0.000000
# 25%     47.416400    1.229375    0.338750        3.679877    1.800000
# 50%    123.812000    7.412500    1.480000        8.698500    3.083000
# 75%    359.000000   18.035900    7.612000       23.820725    4.764750
# max    895.000000   79.900000   99.100000       99.600000   34.950000
#
#         Calcium_mg     Iron_mg  Potassium_mg     Sodium_mg     VitC_mg  \
# count   304.000000  304.000000    304.000000    286.000000   76.000000
# mean     91.328740    1.723374    376.019539    300.455743   29.925342
# std     176.856612    2.262010    389.773791   2304.733896   38.443127
# min       0.000000    0.000000      0.000000      0.000000    0.000000
# 25%       9.980250    0.170000    151.500000      0.447500    3.864500
# 50%      29.500000    0.714300    259.000000     19.205000   16.740000
# 75%     101.500000    2.380750    393.200000    124.000000   41.177500
# max    1498.000000   14.210000   2480.000000  38700.000000  168.100000
#
#        VitB12_ug  Magnesium_mg
# count  51.000000     304.00000
# mean    1.308791      58.30853
# std     1.216080      80.27925
# min     0.000000       0.00000
# 25%     0.478200      11.66500
# 50%     1.060000      22.02000
# 75%     1.710000      71.73750
# max     5.696000     499.70000

# %%
print("\nMissing value counts for nutrient columns:")
print(foundation_combined[nutrients].isnull().sum())
# Out:
# Missing value counts for nutrient columns:
# Calories           30
# Protein_g          11
# Fat_g               9
# Carbohydrate_g     30
# Fiber_g           150
# Calcium_mg         12
# Iron_mg            12
# Potassium_mg       12
# Sodium_mg          30
# VitC_mg           240
# VitB12_ug         265
# Magnesium_mg       12
# dtype: int64

# %%
# Impute Missing Nutrient Values
# For whole foods, if a nutrient is not reported it is often effectively 0.
foundation_combined[nutrients] = foundation_combined[nutrients].fillna(0)
print("\nAfter filling missing nutrient values with 0:")
print(foundation_combined[nutrients].isnull().sum())
# Out:
# After filling missing nutrient values with 0:
# Calories          0
# Protein_g         0
# Fat_g             0
# Carbohydrate_g    0
# Fiber_g           0
# Calcium_mg        0
# Iron_mg           0
# Potassium_mg      0
# Sodium_mg         0
# VitC_mg           0
# VitB12_ug         0
# Magnesium_mg      0
# dtype: int64

# %%
if "Serving_Weight_g" in foundation_combined.columns:
    print("\nFound Serving_Weight_g column. Normalizing nutrient values to per 100g...")
    for nutrient in nutrients:
        foundation_combined[nutrient] = (foundation_combined[nutrient] / foundation_combined["Serving_Weight_g"]) * 100
else:
    print("\nNo Serving_Weight_g column found. Assuming nutrient values are already per 100g.")
# Out:
# No Serving_Weight_g column found. Assuming nutrient values are already per 100g.

# %%
filter_keywords = ["brand", "infant", "supplement", "bone", "peel"]

def is_whole_food(footnote):
    # If footnote is missing, assume it's a whole food.
    if pd.isnull(footnote):
        return True
    footnote_lower = footnote.lower()
    return not any(keyword in footnote_lower for keyword in filter_keywords)


foundation_combined["is_whole_food"] = foundation_combined["footnote"].apply(is_whole_food)
foundation_filtered = foundation_combined[foundation_combined["is_whole_food"] == True].copy()
print("\nAfter filtering based on footnote keywords, sample of filtered data:")
print(foundation_filtered.head(10))
# Out:
# After filtering based on footnote keywords, sample of filtered data:
#    fdc_id  NDB_number                             footnote  Calcium_mg  \
# 0  321358       16158                                  NaN        41.0
# 1  321360      100147                                  NaN        11.0
# 2  321611       11056                                  NaN        36.0
# 3  323121        7022                                  NaN        15.0
# 4  323294       12563   Other phytosterols = 34.67 mg/100g       273.0
# 5  323505       11233                                  NaN       254.0
# 6  323604        1171                                  NaN        55.0
# 7  323697        1172                                  NaN         9.0
# 8  323793        1173                                  NaN       104.0
# 9  324317       11296                                  NaN        28.0
#
#    Carbohydrate_g  Calories  Fiber_g  Iron_mg  Magnesium_mg  Potassium_mg  \
# 0           14.90     243.0      5.4     2.41          71.1         289.0
# 1            5.51      31.0      2.1     0.33          11.9         260.0
# 2            4.11      24.0      0.0     0.78          12.7          97.0
# 3            2.89     310.0      0.0     1.14          11.5         343.0
# 4           16.20     667.0     11.0     3.17         258.0         684.0
# 5            4.42      43.0      4.1     1.60          32.7         348.0
# 6            0.91     146.0      0.0     1.77          11.2         117.0
# 7            0.74      45.0      0.0     0.18          10.6         130.0
# 8            6.02     350.0      0.0     0.00          87.6         959.0
# 9           36.30     293.0      2.4     1.14          20.4         135.0
#
#    Protein_g  Sodium_mg  Fat_g  VitB12_ug  VitC_mg  is_whole_food
# 0       7.35      438.0  17.10       0.00      0.0           True
# 1       0.83        6.0   0.63       0.00     27.2           True
# 2       1.04      282.0   0.39       0.00      0.0           True
# 3      11.70      872.0  28.00       0.97      0.0           True
# 4      20.40      256.0  57.80       0.00      0.0           True
# 5       2.92       53.0   1.49       0.00     93.4           True
# 6      12.30      121.0  10.30       0.00      0.0           True
# 7      10.10      144.0   0.16       0.00      0.0           True
# 8      79.90     1250.0   0.65       0.00      0.0           True
# 9       4.52      374.0  14.40       0.00      1.6           True

# %%
foundation_filtered.drop(columns=["is_whole_food"], inplace=True)

print("\nShape of the filtered foundation data:", foundation_filtered.shape)
print(foundation_filtered[nutrients].describe())
# Out:
# Shape of the filtered foundation data: (316, 15)
#          Calories   Protein_g       Fat_g  Carbohydrate_g     Fiber_g  \
# count  316.000000  316.000000  316.000000      316.000000  316.000000
# mean   184.680143   10.148212    8.838777       19.060163    2.266375
# std    188.705754   10.542301   16.549440       25.652391    4.008425
# min      0.000000    0.000000    0.000000        0.000000    0.000000
# 25%     39.655050    1.055000    0.305350        2.092500    0.000000
# 50%     99.500000    7.179375    1.315000        7.589850    0.350000
# 75%    356.861700   17.832812    6.741000       20.227681    3.154250
# max    895.000000   79.900000   99.100000       99.600000   34.950000
#
#         Calcium_mg     Iron_mg  Potassium_mg     Sodium_mg     VitC_mg  \
# count   316.000000  316.000000    316.000000    316.000000  316.000000
# mean     87.860560    1.657930    361.740316    271.931464    7.197234
# std     174.334138    2.242904    388.995901   2194.013229   22.715052
# min       0.000000    0.000000      0.000000      0.000000    0.000000
# 25%       9.000000    0.140125    143.500000      0.000000    0.000000
# 50%      27.280000    0.607550    249.500000      6.999500    0.000000
# 75%      97.332500    2.295000    378.725000     99.157500    0.000000
# max    1498.000000   14.210000   2480.000000  38700.000000  168.100000
#
#         VitB12_ug  Magnesium_mg
# count  316.000000    316.000000
# mean     0.211229     56.094282
# std      0.683602     79.522603
# min      0.000000      0.000000
# 25%      0.000000     11.055000
# 50%      0.000000     21.150000
# 75%      0.000000     57.100000
# max      5.696000    499.700000

# %%
import pandas as pd


# The nutrient values here are pre-defined
meals = [
    {
        "Meal_ID": 1,
        "Meal_Name": "Oatmeal with Banana & Almonds",
        "Calories": 320,
        "Protein_g": 10,
        "Carbohydrate_g": 40,
        "Fat_g": 12,
        "Fiber_g": 8,
        "Calcium_mg": 150,
        "Iron_mg": 2.1,
        "Potassium_mg": 330,
        "VitC_mg": 6,
        "VitA_ug": 90,
        "VitB12_ug": 0,
        "Magnesium_mg": 50,
        "Vegetarian": "Yes",
        "Contains_DAIRY": "Yes",
        "Contains_GLUTEN": "No",
        "Meal_Type": "Breakfast",
        "Cuisine": "Continental"
    },
    {
        "Meal_ID": 2,
        "Meal_Name": "Grilled Chicken Salad",
        "Calories": 400,
        "Protein_g": 35,
        "Carbohydrate_g": 20,
        "Fat_g": 18,
        "Fiber_g": 5,
        "Calcium_mg": 100,
        "Iron_mg": 3.5,
        "Potassium_mg": 400,
        "VitC_mg": 10,
        "VitA_ug": 120,
        "VitB12_ug": 1.2,
        "Magnesium_mg": 60,
        "Vegetarian": "No",
        "Contains_DAIRY": "No",
        "Contains_GLUTEN": "No",
        "Meal_Type": "Lunch",
        "Cuisine": "Continental"
    },
    {
        "Meal_ID": 3,
        "Meal_Name": "Veggie Stir Fry",
        "Calories": 350,
        "Protein_g": 12,
        "Carbohydrate_g": 60,
        "Fat_g": 10,
        "Fiber_g": 8,
        "Calcium_mg": 120,
        "Iron_mg": 2.0,
        "Potassium_mg": 500,
        "VitC_mg": 15,
        "VitA_ug": 45,
        "VitB12_ug": 0,
        "Magnesium_mg": 40,
        "Vegetarian": "Yes",
        "Contains_DAIRY": "No",
        "Contains_GLUTEN": "No",
        "Meal_Type": "Dinner",
        "Cuisine": "Asian"
    },
    {
        "Meal_ID": 4,
        "Meal_Name": "Fruit & Nut Smoothie",
        "Calories": 250,
        "Protein_g": 8,
        "Carbohydrate_g": 30,
        "Fat_g": 5,
        "Fiber_g": 6,
        "Calcium_mg": 100,
        "Iron_mg": 1,
        "Potassium_mg": 400,
        "VitC_mg": 5,
        "VitA_ug": 90,
        "VitB12_ug": 0,
        "Magnesium_mg": 35,
        "Vegetarian": "Yes",
        "Contains_DAIRY": "Yes",
        "Contains_GLUTEN": "No",
        "Meal_Type": "Snack",
        "Cuisine": "Continental"
    },
    {
        "Meal_ID": 5,
        "Meal_Name": "Quinoa Salad with Black Beans",
        "Calories": 450,
        "Protein_g": 15,
        "Carbohydrate_g": 55,
        "Fat_g": 12,
        "Fiber_g": 10,
        "Calcium_mg": 80,
        "Iron_mg": 3,
        "Potassium_mg": 450,
        "VitC_mg": 8,
        "VitA_ug": 35,
        "VitB12_ug": 0,
        "Magnesium_mg": 55,
        "Vegetarian": "Yes",
        "Contains_DAIRY": "No",
        "Contains_GLUTEN": "Yes",
        "Meal_Type": "Lunch",
        "Cuisine": "Mexican"
    }
]


meals_df = pd.DataFrame(meals)


meals_df.to_csv("meals.csv", index=False)

print("Meals DataFrame:")
print(meals_df)
# Out:
# Meals DataFrame:
#    Meal_ID                      Meal_Name  Calories  Protein_g  \
# 0        1  Oatmeal with Banana & Almonds       320         10
# 1        2          Grilled Chicken Salad       400         35
# 2        3                Veggie Stir Fry       350         12
# 3        4           Fruit & Nut Smoothie       250          8
# 4        5  Quinoa Salad with Black Beans       450         15
#
#    Carbohydrate_g  Fat_g  Fiber_g  Calcium_mg  Iron_mg  Potassium_mg  VitC_mg  \
# 0              40     12        8         150      2.1           330        6
# 1              20     18        5         100      3.5           400       10
# 2              60     10        8         120      2.0           500       15
# 3              30      5        6         100      1.0           400        5
# 4              55     12       10          80      3.0           450        8
#
#    VitA_ug  VitB12_ug  Magnesium_mg Vegetarian Contains_DAIRY Contains_GLUTEN  \
# 0       90        0.0            50        Yes            Yes              No
# 1      120        1.2            60         No             No              No
# 2       45        0.0            40        Yes             No              No
# 3       90        0.0            35        Yes            Yes              No
# 4       35        0.0            55        Yes             No             Yes
#
#    Meal_Type      Cuisine
# 0  Breakfast  Continental
# 1      Lunch  Continental
# 2     Dinner        Asian
# 3      Snack  Continental
# 4      Lunch      Mexican

# %%
# %%writefile app_final_3.py
import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random


meals_df = pd.read_csv("meals.csv")
meal_ids = meals_df["Meal_ID"].tolist()

# ----------------------------
# Fuzzy Logic Functions
# ----------------------------
def triangular(x, a, b, c):
    """Triangular membership function."""
    return np.maximum(np.minimum((x - a) / (b - a), (c - x) / (c - b)), 0)

def age_membership(age):
    return {
        "Young": triangular(age, 0, 18, 30),
        "Adult": triangular(age, 25, 40, 60),
        "Elder": triangular(age, 55, 70, 100)
    }

def bmi_membership(bmi):
    return {
        "Underweight": triangular(bmi, 0, 16, 18.5),
        "Normal": triangular(bmi, 18, 22, 25),
        "Overweight": triangular(bmi, 23, 27, 30),
        "Obese": triangular(bmi, 28, 35, 50)
    }

def activity_membership(activity_level):
    return {
        "Low": triangular(activity_level, 0, 2, 4),
        "Moderate": triangular(activity_level, 3, 5, 7),
        "High": triangular(activity_level, 6, 8, 10)
    }

def fuzzy_health_assessment(age, bmi, activity, diabetes=False, hypertension=False):
    """
    Compute a fuzzy risk score using weighted averages.
    For each factor, we assign:
      - Age: Young=0, Adult=40, Elder=80
      - BMI: Underweight=20, Normal=40, Overweight=60, Obese=80
      - Activity: Low=80, Moderate=50, High=20
    The final risk is the average, adjusted for diabetes (+5) and hypertension (+3).
    """
    age_m = age_membership(age)
    bmi_m = bmi_membership(bmi)
    act_m = activity_membership(activity)

    age_risk = {"Young": 0, "Adult": 40, "Elder": 80}
    bmi_risk = {"Underweight": 20, "Normal": 40, "Overweight": 60, "Obese": 80}
    act_risk = {"Low": 80, "Moderate": 50, "High": 20}

    age_risk_val = sum(age_m[cat] * age_risk[cat] for cat in age_m) / (sum(age_m.values()) + 1e-6)
    bmi_risk_val = sum(bmi_m[cat] * bmi_risk[cat] for cat in bmi_m) / (sum(bmi_m.values()) + 1e-6)
    act_risk_val = sum(act_m[cat] * act_risk[cat] for cat in act_m) / (sum(act_m.values()) + 1e-6)

    risk_score = (age_risk_val + bmi_risk_val + act_risk_val) / 3
    if diabetes:
        risk_score += 5
    if hypertension:
        risk_score += 3
    risk_score = np.clip(risk_score, 0, 100)

    if risk_score < 35:
        risk_category = "Low"
    elif risk_score < 60:
        risk_category = "Medium"
    else:
        risk_category = "High"

    explanation = {
        "Age Risk Value": age_risk_val,
        "BMI Risk Value": bmi_risk_val,
        "Activity Risk Value": act_risk_val,
        "Final Risk Score": risk_score
    }
    return risk_score, risk_category, explanation

def get_recommendations(age, risk_category):
    """
    Provide personalized nutrient recommendations based on risk and age.
    """
    if risk_category == "High":
        base_cal = 1800
        protein_rec = "High"
    elif risk_category == "Medium":
        base_cal = 2100
        protein_rec = "Moderate"
    else:
        base_cal = 2500
        protein_rec = "Moderate"
    if age > 60:
        base_cal -= 200
    return {
        "Recommended Calories": base_cal,
        "Protein": protein_rec,
        "Fat": "Low" if risk_category == "High" else "Moderate",
        "Carbs": "Moderate" if risk_category != "Low" else "High"
    }

# ----------------------------
# Genetic Algorithm (GA) Functions
# ----------------------------
POPULATION_SIZE = 20
NUM_DAYS = 7
MEALS_PER_DAY = 3
CHROMOSOME_LENGTH = NUM_DAYS * MEALS_PER_DAY
GENERATIONS = 50
TARGET_CALORIES = 2100

w_macro = 0.5
w_variety = 0.3
w_allergy = 0.2

def fitness_function(chromosome, vegetarian, no_dairy, high_protein):
    plan = meals_df[meals_df["Meal_ID"].isin(chromosome)]
    total_calories = plan["Calories"].sum()
    target_weekly = TARGET_CALORIES * 7
    macro_diff_score = abs(target_weekly - total_calories)
    variety_score = CHROMOSOME_LENGTH - len(set(chromosome))

    penalty = 0
    if vegetarian:
        non_veg = plan[plan["Vegetarian"]=="No"].shape[0]
        penalty += non_veg * 50
    if no_dairy:
        dairy = plan[plan["Contains_DAIRY"]=="Yes"].shape[0]
        penalty += dairy * 50
    protein_total = plan["Protein_g"].sum()
    avg_protein = protein_total / CHROMOSOME_LENGTH
    if high_protein:
        if avg_protein < 10:
            penalty += (10 - avg_protein) * 100
        else:
            penalty -= 50
    return w_macro * macro_diff_score + w_variety * variety_score + w_allergy * penalty

def create_chromosome():
    return [random.choice(meal_ids) for _ in range(CHROMOSOME_LENGTH)]

def tournament_selection(population, k=3, vegetarian=False, no_dairy=False, high_protein=False):
    selected = random.sample(population, k)
    selected.sort(key=lambda chromo: fitness_function(chromo, vegetarian, no_dairy, high_protein))
    return selected[0]

def crossover(parent1, parent2):
    day = random.randint(0, NUM_DAYS - 1)
    start = day * MEALS_PER_DAY
    end = start + MEALS_PER_DAY
    child1 = parent1.copy()
    child2 = parent2.copy()
    child1[start:end], child2[start:end] = parent2[start:end], parent1[start:end]
    return child1, child2

def mutate(chromosome, mutation_rate=0.15):
    new_chromosome = chromosome.copy()
    for i in range(CHROMOSOME_LENGTH):
        if random.random() < mutation_rate:
            new_chromosome[i] = random.choice(meal_ids)
    return new_chromosome

# Use session state to store GA results so that changing the selectbox doesn't rerun the GA.
if "ga_result" not in st.session_state:
    st.session_state.ga_result = None
    st.session_state.fitness_history = None

def run_ga(vegetarian, no_dairy, high_protein):
    population = [create_chromosome() for _ in range(POPULATION_SIZE)]
    best_chromo = None
    best_fit = float('inf')
    fitness_history = []
    for generation in range(GENERATIONS):
        new_population = []
        population.sort(key=lambda chromo: fitness_function(chromo, vegetarian, no_dairy, high_protein))
        new_population.extend(population[:2])
        while len(new_population) < POPULATION_SIZE:
            parent1 = tournament_selection(population, vegetarian=vegetarian, no_dairy=no_dairy, high_protein=high_protein)
            parent2 = tournament_selection(population, vegetarian=vegetarian, no_dairy=no_dairy, high_protein=high_protein)
            child1, child2 = crossover(parent1, parent2)
            child1 = mutate(child1, mutation_rate=0.15)
            child2 = mutate(child2, mutation_rate=0.15)
            new_population.extend([child1, child2])
        population = new_population[:POPULATION_SIZE]
        current_best = min(population, key=lambda chromo: fitness_function(chromo, vegetarian, no_dairy, high_protein))
        current_fit = fitness_function(current_best, vegetarian, no_dairy, high_protein)
        if current_fit < best_fit:
            best_fit = current_fit
            best_chromo = current_best
        fitness_history.append(best_fit)
    return best_chromo, fitness_history

# ----------------------------
# Streamlit App Layout with Tabs
# ----------------------------
st.set_page_config(page_title="Fuzzy-GA Diet Planner", layout="wide")
st.title("Fuzzy-GA Powered Diet Planner")

with st.sidebar:
    st.title("Fuzzy-GA Diet Planner")
    st.markdown(
        """
        **About:**
        This app uses fuzzy logic to assess your health risk based on your Age, BMI, and Activity Level.
        It then provides personalized nutrient recommendations and uses a genetic algorithm (GA)
        to generate an optimized weekly meal plan tailored to your dietary preferences.
        """
    )

# Tabs for Navigation
tabs = st.tabs(["Overview", "Health Assessment", "Meal Plan Optimization", "Membership Functions"])

# ----------------------------
# Tab 1: Overview
# ----------------------------
with tabs[0]:
    st.header("Overview")
    st.markdown(
        """
        **Fuzzy-GA Powered Diet Planner** integrates:
        - A **Fuzzy Logic Engine** to evaluate your health risk and provide nutrient recommendations.
        - A **Genetic Algorithm** to optimize a weekly meal plan that fits your nutritional needs and dietary preferences.

        Use the tabs to explore:
        - Your health assessment based on your inputs.
        - The optimized meal plan and detailed nutrient breakdowns.
        - Interactive membership function plots that explain the fuzzy logic.
        """
    )

# ----------------------------
# Tab 2: Health Assessment
# ----------------------------
with tabs[1]:
    st.header("Health Assessment")
    col1, col2 = st.columns(2)
    with col1:
        st.subheader("Enter Your Health Details")
        user_age = st.number_input("Age", min_value=0, max_value=120, value=30, key="age")
        user_bmi = st.number_input("BMI", min_value=10.0, max_value=50.0, value=22.0, step=0.1, key="bmi")
        user_activity = st.slider("Activity Level (0 low - 10 high)", 0, 10, 5, key="activity")
        user_diabetes = st.checkbox("Diabetes", value=False, key="diabetes")
        user_hypertension = st.checkbox("Hypertension", value=False, key="hypertension")
    with col2:
        risk, risk_cat, fuzzy_expl = fuzzy_health_assessment(user_age, user_bmi, user_activity, user_diabetes, user_hypertension)
        recs = get_recommendations(user_age, risk_cat)
        st.subheader("Your Health Summary")
        st.markdown(f"**Risk Score:** {risk:.2f} ({risk_cat} Risk)")
        st.markdown("**Nutrient Recommendations:**")
        st.write(recs)
    st.markdown("---")
    st.markdown("**Fuzzy Logic Explanation:**")
    st.json(fuzzy_expl)

# ----------------------------
# Tab 3: Meal Plan Optimization
# ----------------------------
with tabs[2]:
    st.header("Meal Plan Optimization")
    st.markdown("Click the button below to generate an optimized weekly meal plan based on your dietary preferences.")
    dietary_veg = st.checkbox("Vegetarian", value=False, key="veg")
    dietary_no_dairy = st.checkbox("No Dairy", value=False, key="no_dairy")
    dietary_high_protein = st.checkbox("High Protein", value=False, key="high_protein")

    # Check if GA result is stored in session_state; if not, run GA when button clicked.
    if st.button("Generate Meal Plan"):
        with st.spinner("Optimizing your meal plan..."):
            best_plan, fitness_history = run_ga(dietary_veg, dietary_no_dairy, dietary_high_protein)
            st.session_state.ga_result = best_plan
            st.session_state.fitness_history = fitness_history
        st.success("Meal plan generated!")

    if st.session_state.ga_result is not None:
        # GA Evolution Chart
        st.subheader("GA Evolution")
        fig_ga, ax_ga = plt.subplots(figsize=(8, 4))
        ax_ga.plot(st.session_state.fitness_history, marker='o', linestyle='-')
        ax_ga.set_xlabel("Generation")
        ax_ga.set_ylabel("Best Fitness")
        ax_ga.set_title("GA Evolution: Fitness over Generations")
        st.pyplot(fig_ga)

        # Display Optimized Weekly Meal Plan
        plan_df = pd.DataFrame(np.array(st.session_state.ga_result).reshape(NUM_DAYS, MEALS_PER_DAY),
                               columns=["Meal 1", "Meal 2", "Meal 3"])
        st.subheader("Optimized Weekly Meal Plan")
        st.dataframe(plan_df)

        # Daily Nutrient Totals
        daily_totals = []
        for day in range(NUM_DAYS):
            day_ids = st.session_state.ga_result[day*MEALS_PER_DAY:(day+1)*MEALS_PER_DAY]
            day_plan = meals_df[meals_df["Meal_ID"].isin(day_ids)]
            totals = {
                "Calories": day_plan["Calories"].sum(),
                "Protein": day_plan["Protein_g"].sum(),
                "Carbohydrates": day_plan["Carbohydrate_g"].sum(),
                "Fat": day_plan["Fat_g"].sum(),
                "Fiber": day_plan["Fiber_g"].sum()
            }
            daily_totals.append(totals)
        daily_df = pd.DataFrame(daily_totals)
        st.subheader("Daily Nutrient Totals")
        st.dataframe(daily_df)

        # Interactive Meal Nutrient Breakdown
        st.subheader("View Meal Nutrient Breakdown")
        # Use a selectbox with a key to preserve state
        meal_choice = st.selectbox("Select a Meal ID from the Optimized Plan", sorted(set(st.session_state.ga_result)), key="meal_select")
        selected_meal = meals_df[meals_df["Meal_ID"]==meal_choice].iloc[0]
        fig_meal, ax_meal = plt.subplots(figsize=(8, 4))
        meal_nutrients = ["Calories", "Protein_g", "Carbohydrate_g", "Fat_g", "Fiber_g"]
        nutrient_values = [selected_meal[n] for n in meal_nutrients]
        ax_meal.bar(meal_nutrients, nutrient_values, color="skyblue")
        ax_meal.set_ylabel("Value")
        ax_meal.set_title(f"Nutrient Breakdown: {selected_meal['Meal_Name']}")
        st.pyplot(fig_meal)
    else:
        st.info("Click 'Generate Meal Plan' to optimize your weekly meal plan.")

# ----------------------------
# Tab 4: Membership Functions
# ----------------------------
with tabs[3]:
    st.header("Membership Function Plots")
    st.markdown("These plots illustrate the membership functions used for Age, BMI, and Activity.")

    st.subheader("Age Membership Functions")
    x_age = np.linspace(0, 100, 500)
    fig_age, ax_age = plt.subplots(figsize=(8, 4))
    ax_age.plot(x_age, [age_membership(x)["Young"] for x in x_age], label="Young")
    ax_age.plot(x_age, [age_membership(x)["Adult"] for x in x_age], label="Adult")
    ax_age.plot(x_age, [age_membership(x)["Elder"] for x in x_age], label="Elder")
    ax_age.set_xlabel("Age")
    ax_age.set_ylabel("Membership Degree")
    ax_age.set_title("Age Membership Functions")
    ax_age.legend()
    st.pyplot(fig_age)

    st.subheader("BMI Membership Functions")
    x_bmi = np.linspace(0, 50, 500)
    fig_bmi, ax_bmi = plt.subplots(figsize=(8, 4))
    ax_bmi.plot(x_bmi, [bmi_membership(x)["Underweight"] for x in x_bmi], label="Underweight")
    ax_bmi.plot(x_bmi, [bmi_membership(x)["Normal"] for x in x_bmi], label="Normal")
    ax_bmi.plot(x_bmi, [bmi_membership(x)["Overweight"] for x in x_bmi], label="Overweight")
    ax_bmi.plot(x_bmi, [bmi_membership(x)["Obese"] for x in x_bmi], label="Obese")
    ax_bmi.set_xlabel("BMI")
    ax_bmi.set_ylabel("Membership Degree")
    ax_bmi.set_title("BMI Membership Functions")
    ax_bmi.legend()
    st.pyplot(fig_bmi)

    st.subheader("Activity Membership Functions")
    x_act = np.linspace(0, 10, 500)
    fig_act, ax_act = plt.subplots(figsize=(8, 4))
    ax_act.plot(x_act, [activity_membership(x)["Low"] for x in x_act], label="Low")
    ax_act.plot(x_act, [activity_membership(x)["Moderate"] for x in x_act], label="Moderate")
    ax_act.plot(x_act, [activity_membership(x)["High"] for x in x_act], label="High")
    ax_act.set_xlabel("Activity Level")
    ax_act.set_ylabel("Membership Degree")
    ax_act.set_title("Activity Membership Functions")
    ax_act.legend()
    st.pyplot(fig_act)
# Out:
# Overwriting app_final_3.py
